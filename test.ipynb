# %%
import joblib

obj = joblib.load("src/saved_models/PyTorch.pkl")
print("Тип объекта в файле:", type(obj).__name__)
print("Есть .predict?:", hasattr(obj, "predict"))
print("Есть .model?:", hasattr(obj, "model"))
